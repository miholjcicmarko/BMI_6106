# %% [markdown]
# ## Exam 2 (Due May 4, 2020 at 11:59 pm)
#
# Please read each question carefully and apply the necessary exploratory analysis to each data set, as well as test for the assumptions relevant to each method when appropriate.
#
# Write the answers in the space provided below each question.

# %% [markdown]
# ### $1$. Small sample sizes affects accuracy of a t-test because the distribution resembles a normal distribution.
#
# a. True
#
# b. False

# %%
library(pwr)
pwr.t.test(n = 30, d = 0.2, sig.level = 0.05, type = "paired")
# Out:
#      Paired t test power calculation
#
#               n = 30
#               d = 0.2
#       sig.level = 0.05
#           power = 0.1851834
#     alternative = two.sided
#
# NOTE: n is number of *pairs*

# %%
pwr.t.test(n = 100, d = 0.2, sig.level = 0.05, type = "paired")
# Out:
#      Paired t test power calculation
#
#               n = 100
#               d = 0.2
#       sig.level = 0.05
#           power = 0.5082648
#     alternative = two.sided
#
# NOTE: n is number of *pairs*

# %% [markdown]
# The answer is true.

# %% [markdown]
# T-test accuracy is affected by the sample size. Power is defined as the probability that a test correctly rejects the null hypothesis when the specific alternative hypothesis is actually true. Therefore, power is related to the accuracy of the measurement. Above, the calculations of different powers are shown. The larger the sample size, the larger the power. Therefore, the larger the sample size, the probability that the t-test will make a mistake decreases.
#
# Additionally, the t-test distribution resembles a normal distribution. The t distribution is similar to the normal distribution because it is symmetric and mound shaped. The t-distribution is slightly different from the normal distribution because it is thicker at the tails to allow for more uncertainty. This difference is minimal as the t-distribution still resembles a normal distribution. Normal distributions become steeper with more samples. The same can be said for t-distributions. The increase in sample size will help better define the confidence interval in the t-distribution. As a result, the t-test will become more accurate. Therefore, sample sizes affect the accuracy of a t-test.

# %% [markdown]
# ### $2$. Data on 102 male and 100 female athletes were collected at the Australian Institute of Sport. The data are  in the file ais.txt.
#
# Develop a logistic regression model for gender ( y = 1 corresponds to female) or ( y = 0 corresponds to male) based on the following predictors (which is a subset of those available):
#
# - RCC, read cell count
# - WCC, white cell count
# - BMI, body mass index
#
# Remember to check for the model assumptions.

# %%
library(dplyr)
library(ggplot2)
library(mosaic)
library(swirl)
library(e1071)
library(mosaic)

# %%
df <- read.table("ais.txt", header = TRUE, sep = " ")
df <- subset(df, select = -X)

# %%
logreg <- glm(Sex ~ RCC + WCC + BMI, family = "binomial", data = df) 
msummary(logreg)
# Out:
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept) 29.29399    3.92411   7.465 8.32e-14 ***
# RCC         -5.34706    0.72118  -7.414 1.22e-13 ***
# WCC          0.15505    0.12190   1.272  0.20338
# BMI         -0.22911    0.08723  -2.626  0.00863 **
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 280.01  on 201  degrees of freedom
# Residual deviance: 147.01  on 198  degrees of freedom
# AIC: 155.01
#
# Number of Fisher Scoring iterations: 5

# %% [markdown]
# Model Assumptions:
# The observations were obtained independently and randomly from the population.
# The male and female groups were normally distributed.
# These normal populations have a common variance.

# %%
males <- which(df$Sex == 0)
males <- df[males,]

females <- which(df$Sex == 1)
females <- df[females,]

# %%
favstats(males$RCC)
boxplot(males$RCC, ylab = "RCC", main = "Boxplot of Males")
skew <- skewness(males$RCC)
cat("Skewness: ", skew, "\n")
d <- sd(males$RCC)
cat("Standard Deviation: ", d)
# Out:
#  min  Q1     median Q3     max  mean     sd        n   missing
#  4.13 4.8625 5.015  5.1775 6.72 5.026569 0.3507234 102 0
# Skewness:  0.9105337
# Standard Deviation:  0.3507234
# Plot with title “Boxplot of Males”

# %%
favstats(females$RCC)
boxplot(females$RCC, ylab = "RCC", main = "Boxplot of Females")
skew <- skewness(females$RCC)
cat("Skewness: ", skew, "\n")
d <- sd(females$RCC)
cat("Standard Deviation: ", d)
# Out:
#  min Q1     median Q3     max  mean   sd        n   missing
#  3.8 4.1675 4.385  4.5375 5.33 4.4045 0.3208964 100 0
# Skewness:  0.6822899
# Standard Deviation:  0.3208964
# Plot with title “Boxplot of Females”

# %%
favstats(males$WCC)
boxplot(males$WCC, ylab = "WCC", main = "Boxplot of Males")
skew <- skewness(males$WCC)
cat("Skewness: ", skew, "\n")
d <- sd(males$WCC)
cat("Standard Deviation: ", d)
# Out:
#  min Q1    median Q3    max  mean     sd       n   missing
#  3.9 6.025 7.1    8.375 14.3 7.221078 1.899602 102 0
# Skewness:  0.8468776
# Standard Deviation:  1.899602
# Plot with title “Boxplot of Males”

# %%
favstats(females$WCC)
boxplot(females$WCC, ylab = "WCC", main = "Boxplot of Males")
skew <- skewness(females$WCC)
cat("Skewness: ", skew, "\n")
d <- sd(females$WCC)
cat("Standard Deviation: ", d)
# Out:
#  min Q1  median Q3   max  mean  sd       n   missing
#  3.3 5.8 6.7    7.95 13.3 6.994 1.695438 100 0
# Skewness:  0.7391087
# Standard Deviation:  1.695438
# Plot with title “Boxplot of Males”

# %%
favstats(males$BMI)
boxplot(males$BMI, ylab = "BMI", main = "Boxplot of Males")
skew <- skewness(males$BMI)
cat("Skewness: ", skew, "\n")
d <- sd(males$BMI)
cat("Standard Deviation: ", d)
# Out:
#  min   Q1    median Q3     max   mean     sd      n   missing
#  19.63 22.29 23.56  25.155 34.42 23.90363 2.76748 102 0
# Skewness:  1.390554
# Standard Deviation:  2.76748
# Plot with title “Boxplot of Males”

# %%
favstats(females$BMI)
boxplot(females$BMI, ylab = "WCC", main = "Boxplot of Males")
skew <- skewness(females$BMI)
cat("Skewness: ", skew, "\n")
d <- sd(females$BMI)
cat("Standard Deviation: ", d)
# Out:
#  min   Q1      median Q3      max   mean    sd       n   missing
#  16.75 20.2675 21.815 23.3875 31.93 21.9892 2.640028 100 0
# Skewness:  0.6830202
# Standard Deviation:  2.640028
# Plot with title “Boxplot of Males”

# %% [markdown]
# None of the distributions are completely normal. However, none of the distributions are immensely skewed. There is not a large difference in the standard deviation between the different distributions.

# %% [markdown]
# ### $3$. If scores are normally distributed with a mean of 42 and a standard deviation of 8, what percent of the scores is:
#
# (a) greater than 25?
#
# (b) smaller than 31?
#
# (c) between 25 and 31?

# %% [markdown]
# Problem 3a

# %%
prob = 1 - pnorm(25,mean = 42,sd = 8)
cat("percent of scores greater than 25: ", prob, "\n")
# Out:
# percent of scores greater than 25:  0.9832067

# %% [markdown]
# Problem 3b

# %%
prob = pnorm(31,mean = 42,sd = 8)
cat("percent of scores smaller than 31: ", prob, "\n")
# Out:
# percent of scores smaller than 31:  0.08456572

# %% [markdown]
# Problem 3c

# %%
prob = pnorm(31,mean = 42,sd = 8) - pnorm(25,mean = 42,sd = 8)
cat("percent of scores between 25 and 31: ", prob, "\n")
# Out:
# percent of scores between 25 and 31:  0.06777242

# %% [markdown]
# ### $4$. From the following table:
# ![title](table1.png)
#
# a. Apply the appropiate tests to evaluate the null hypothesis that there is no difference in the noise values means at different vehicle sizes.
#
# b. Examine all assumptions related to the test and make sure that the data follows all of those assumptions.

# %% [markdown]
# null hypothesis: there is no difference in the noise values means at different vehicle sizes.
# alternative hypothesis: there is a difference in the noise values means at different vehicle sizes

# %%
small <- c(810, 820, 820, 835, 835, 835)
medium <- c(840, 840, 840, 845, 855, 850)
large <- c(785, 790, 785, 760, 760, 770)

# %% [markdown]
# Bonferroni Correction was used because multiple t-tests were performed. This correction decreases the probability of a type 1 error occuring. The p-value will be determined by the Bonferroni Correction.

# %%
p_value = 0.05/3
cat("p_value: ", p_value)
# Out:
# p_value:  0.01666667

# %%
ttest = t.test(medium, small, alternative = "two.sided", paired = FALSE, var.equal = FALSE)
ttest
# Out:
# 	Welch Two Sample t-test
#
# data:  medium and small
# t = 3.7812, df = 8.1206, p-value = 0.005234
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#   7.507747 30.825587
# sample estimates:
# mean of x mean of y
#  845.0000  825.8333

# %% [markdown]
# There is a significant difference between the noise value of small and medium sized vehicles. The 95% confidence interval does not include 0. Additionally, the p-value is lower than 0.0167. Therefore, we can conclude that there is a significant difference between the two vehicle sizes.

# %% [markdown]
# Medium sized vehicles have larger noise values than small sized vehicles.

# %%
ttest = t.test(medium, large, alternative = "two.sided", paired = FALSE, var.equal = FALSE)
ttest
# Out:
# 	Welch Two Sample t-test
#
# data:  medium and large
# t = 11.56, df = 7.1176, p-value = 7.189e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  55.72933 84.27067
# sample estimates:
# mean of x mean of y
#       845       775

# %% [markdown]
# There is a significant difference between the noise value of medium and large sized vehicles. The 95% confidence interval does not include 0. Additionally, the p-value is lower than 0.0167. Therefore, we can conclude that there is a significant difference between the two vehicle sizes.

# %% [markdown]
# Medium sized vehicles have larger noise values than large sized vehicles.

# %%
ttest = t.test(small, large, alternative = "two.sided", paired = FALSE, var.equal = FALSE)
ttest
# Out:
# 	Welch Two Sample t-test
#
# data:  small and large
# t = 7.2598, df = 9.523, p-value = 3.54e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  35.12537 66.54129
# sample estimates:
# mean of x mean of y
#  825.8333  775.0000

# %% [markdown]
# There is a significant difference between the noise value of small and large sized vehicles. The 95% confidence interval does not include 0. Additionally, the p-value is lower than 0.0167. Therefore, we can conclude that there is a significant difference between the two vehicle sizes.

# %% [markdown]
# Small sized vehicles have larger noise values than large sized vehicles.

# %% [markdown]
# We have to reject the null hypothesis. There is a difference in the noise values means at different vehicle sizes.

# %% [markdown]
# The assumptions that relate to the t-test are that the data was randomly sampled, the data distribution is normal, the sample sample size is adequate and there is no equality of variance in standard deviation.
#
# We assume that the data was randomly sampled. We will assume that the sample size is adequate for comparison.

# %% [markdown]
# The following boxplots will show that the data is normally distributed.

# %%
library(e1071)
library(mosaic)

# %%
favstats(small)
boxplot(small, ylab = "Noise", main = "Boxplot of Small Vehicle Noise")
skew <- skewness(small)
cat("Skewness: ", skew)
# Out:
#  min Q1  median Q3  max mean     sd       n missing
#  810 820 827.5  835 835 825.8333 10.68488 6 0
# Skewness:  -0.2808465
# Plot with title “Boxplot of Small Vehicle Noise”

# %% [markdown]
# The small vehicle data is slightly skewed. It is adequately normal for a t-test.

# %%
favstats(medium)
boxplot(medium, ylab = "Noise", main = "Boxplot of Medium Vehicle Noise")
skew <- skewness(medium)
cat("Skewness: ", skew)
# Out:
#  min Q1  median Q3     max mean sd       n missing
#  840 840 842.5  848.75 855 845  6.324555 6 0
# Skewness:  0.4941059
# Plot with title “Boxplot of Medium Vehicle Noise”

# %% [markdown]
# The medium vehicle data is slightly skewed. It is adequately normal for a t-test.

# %%
favstats(large)
boxplot(large, ylab = "Noise", main = "Boxplot of Medium Vehicle Noise")
skew <- skewness(large)
cat("Skewness: ", skew)
# Out:
#  min Q1    median Q3  max mean sd       n missing
#  760 762.5 777.5  785 790 775  13.41641 6 0
# Skewness:  -0.1035217
# Plot with title “Boxplot of Medium Vehicle Noise”

# %% [markdown]
# The large vehicle data is slightly skewed. It is adequately normal for a t-test.

# %%
small_d <- sd(small)
cat("standard deviation: ", small_d, "\n")
med_d <- sd(medium)
cat("standard deviaiton: ", med_d, "\n")
large_d <- sd(large)
cat("standard deviation: ", large_d)
# Out:
# standard deviation:  10.68488
# standard deviaiton:  6.324555
# standard deviation:  13.41641

# %% [markdown]
# There are slight differences in the standard deviation across the three categories.

# %% [markdown]
# ### $5$. From the BABNEW.dta dataset use the appropiate statistical test to evaluate difference in birth weight (bweight)  as a function of gender (sex).
#
# Solve the exercise manually using the steps given in lecture and then confirm the results with the R function.

# %%
library(foreign)
library(tidyverse)
library(dplyr)
babnew <- read.dta("./BABNEW.dta", convert.factors = T)
library(magrittr)

# %%
mean_male <- mean(babnew$bweight[which(babnew$sex == "male")])

len_m <- length(babnew$bweight[which(babnew$sex == "male")])

mean_female <- mean(babnew$bweight[which(babnew$sex == "female")])

len_f <- length(babnew$bweight[which(babnew$sex == "female")])

sd_male <- sd(babnew$bweight[which(babnew$sex == "male")])

sd_female <- sd(babnew$bweight[which(babnew$sex == "female")])

t_val_m <- qt(0.975,len_m)
t_val_f <- qt(0.975,len_f)

male_upper <- mean_male + (t_val_m * (sd_male / sqrt(len_m)))
male_lower <- mean_male - (t_val_m * (sd_male / sqrt(len_m)))

cat("95% confidence interval of Mean of Males ", male_lower, " to ", male_upper, "\n")

female_upper <- mean_female + (t_val_f * (sd_female / sqrt(len_m)))
female_lower <- mean_female - (t_val_f * (sd_female / sqrt(len_m)))

cat("95% confidence interval of Mean of Females ", female_lower, " to ", female_upper)
# Out:
# 95% confidence interval of Mean of Males  3138.716  to  3283.842
# 95% confidence interval of Mean of Females  2975.621  to  3112.633

# %% [markdown]
# There is a significant difference between the males and females. The 95% confidence intervals of the mean do not overlap. Therefore, we can conclude that there is a difference. Looking at the confidence intervals, we see that males have a larger mean weight.

# %%
male <- babnew$bweight[which(babnew$sex == "male")]
lm <- length(male)
cat("Length of male data points: ", lm, "\n")
female <- babnew$bweight[which(babnew$sex == "female")]
lf <- length(female)
cat("Length of female data points: ", lf, "\n")

sd_m <- sd(male)
sd_f <- sd(female)

cat("Standard Deviation of Male: ", sd_m, "\n")
cat("Standard Deviation of Female: ", sd_f)
# Out:
# Length of male data points:  326
# Length of female data points:  315
# Standard Deviation of Male:  665.9798
# Standard Deviation of Female:  628.6603

# %%
ttest = t.test(male, female, alternative = "two.sided", paired = FALSE, var.equal = FALSE)
ttest
# Out:
# 	Welch Two Sample t-test
#
# data:  male and female
# t = 3.2686, df = 638.65, p-value = 0.001139
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#   66.73186 267.57246
# sample estimates:
# mean of x mean of y
#  3211.279  3044.127

# %% [markdown]
# Significant difference between the mean birth weights of the two genders. The p-value is below 0.05. Additionally, the 95% confidence interval does not include 0. Therefore, we can conclude that there is a difference. The t-test tells us that the males have a larger mean weight than women.
#
# This conclusion matches the conclusion of the manual testing.

# %% [markdown]
# ### $6$. The following data reports the calorie content of beef hot dogs. Here are the numbers of calories of a random sample of 20 different hot dogs:
#
# 186, 181, 176, 149, 184, 190, 158, 139, 175, 148, 152, 111, 141, 153, 190, 157, 131, 149, 135, 132.
#
# Assume that these numbers are the observed values from a random sample of twenty independent normal random variables with mean μ and variance σ2, both unknown. Find the 90% confidence intervals for the mean number of calories μ.

# %% [markdown]
# $(\bar{x} - t_{n-1,1_{-\alpha/2}}s/\sqrt{n},\bar{x} + t_{n-1,1_{-\alpha/2}}s/\sqrt{n}) $

# %%
bhd = c(186, 181, 176, 149, 184, 190, 158, 139, 175, 148, 152, 111, 141, 153, 190, 157, 131, 149, 135, 132)
mean_bhd <- mean(bhd)
sd_bhd <- sd(bhd)
l_bhd <- length(bhd)
t_val <- qt(0.95,l_bhd)

c_upper <- mean_bhd + (t_val * (sd_bhd / sqrt(l_bhd)))
c_lower <- mean_bhd - (t_val * (sd_bhd / sqrt(l_bhd)))

cat("This is the 90% confidence interval of the Mean number of calories: ", c_lower, " to ", c_upper, "\n")
# Out:
# This is the 90% confidence interval of the Mean number of calories:  148.1179  to  165.5821

# %% [markdown]
# ### $7$. Which type of predictor variables can be included in a General Linear Model
#
# a. Logistic
#
# b. Normal
#
# c. Categorical
#
# d. continuous
#
# e. Mixed

# %% [markdown]
# The type of predictor variables that can be included in a General Linear Model are continuous and categorical variables.

# %% [markdown]
# ### $8$. The file anscombe.txt contains 4 different datasets constructed by Anscombe in 1973. The x and y variables are matched to each dataset respectively (e.g. x1 corresponds to y1, etc). A. Produce a Simple linear regression for each dataset (a scatterplot might also help you to see the differences). B. Write the resulting linear function for each model. C. Generate residuals plots D. In a few sentences discuss each model and what might be the problem (if any) with that model and what can be done to fix it.

# %%
df <- read.table("anscombe.txt", header = TRUE)
df
# Out:
#    case x1 x2 x3 x4 y1    y2   y3    y4
# 1   1   10 10 10  8  8.04 9.14  7.46  6.58
# 2   2    8  8  8  8  6.95 8.14  6.77  5.76
# 3   3   13 13 13  8  7.58 8.74 12.74  7.71
# 4   4    9  9  9  8  8.81 8.77  7.11  8.84
# 5   5   11 11 11  8  8.33 9.26  7.81  8.47
# 6   6   14 14 14  8  9.96 8.10  8.84  7.04
# 7   7    6  6  6  8  7.24 6.13  6.08  5.25
# 8   8    4  4  4 19  4.26 3.10  5.39 12.50
# 9   9   12 12 12  8 10.84 9.13  8.15  5.56
# 10 10    7  7  7  8  4.82 7.26  6.42  7.91
# 11 11    5  5  5  8  5.68 4.74  5.73  6.89

# %% [markdown]
# Model for x1y1 dataset

# %%
mod1 <- lm(df$y1 ~ df$x1)
plot(df$x1, df$y1)
abline(mod1, lwd=2)
grid(nx = NULL,ny = NULL)
msummary(mod1)
# Out:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   3.0001     1.1247   2.667  0.02573 *
# df$x1         0.5001     0.1179   4.241  0.00217 **
#
# Residual standard error: 1.237 on 9 degrees of freedom
# Multiple R-squared:  0.6665,	Adjusted R-squared:  0.6295
# F-statistic: 17.99 on 1 and 9 DF,  p-value: 0.00217
# plot without title

# %%
plot(df$x1, df$y1, xlab = "x1", ylab = "y1", main = "Model 1", xlim=c(3, 16))
abline(mod1, lwd=2)
grid(nx = NULL,ny = NULL)

res <- signif(residuals(mod1), 3)
pre <- predict(mod1) # plot distances between points and the regression line
segments(df$x1, df$y1, df$x1, pre, col="red")

# add labels (residual values) to points
#install.packages("calibrate")
library(calibrate)
textxy(df$x1, df$y1, res, cex=0.75)
# Out:
# Plot with title “Model 1”

# %%
plot(df$y1, res, xlab = "predicted", ylab = "actual", main = "Residual Plot for Model 1")
# Out:
# Plot with title “Residual Plot for Model 1”

# %% [markdown]
# Part D Model 1
# The first model has an R squared value of 0.6295. This means that the model moderately fits the data. There are five points out of ten data points that have large residual values. This fact provides more evidence that the model could use improvement. We can try non-linear models to determine if we can achieve a higher R squared value. A cubic function might be a good approximator of the data. This is because inflection point can fit across the lateral data points. The tails of the function can reach the extremes that occur at the corners of the visible grid of data.

# %%
mod2 <- lm(df$y2 ~ df$x2)
plot(df$x2, df$y2)
abline(mod2, lwd=2)
grid(nx = NULL,ny = NULL)
msummary(mod2)
# Out:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)    3.001      1.125   2.667  0.02576 *
# df$x2          0.500      0.118   4.239  0.00218 **
#
# Residual standard error: 1.237 on 9 degrees of freedom
# Multiple R-squared:  0.6662,	Adjusted R-squared:  0.6292
# F-statistic: 17.97 on 1 and 9 DF,  p-value: 0.002179
# plot without title

# %%
plot(df$x2, df$y2, xlab = "x2", ylab = "y2", main = "Model 2", xlim=c(4, 15), ylim=c(3, 10))
abline(mod2, lwd=2)
grid(nx = NULL,ny = NULL)

res <- signif(residuals(mod2), 5)
pre <- predict(mod2) # plot distances between points and the regression line
segments(df$x2, df$y2, df$x2, pre, col="red")

# add labels (residual values) to points
#install.packages("calibrate")
library(calibrate)
textxy(df$x2, df$y2, res, cex=0.75)
# Out:
# Plot with title “Model 2”

# %%
plot(df$y2, res, xlab = "predicted", ylab = "actual", main = "Residual Plot for Model 2")
# Out:
# Plot with title “Residual Plot for Model 2”

# %% [markdown]
# Part D Model 2
# The second model has an R squared value of 0.6292. This means that the model moderately fits the data. There are seven points out of nine data points that have large residual values. This fact provides more evidence that the model could use improvement. We can try non-linear models to determine if we can achieve a higher R squared value. I believe that a quadratic model should be experimented with. The data seems to resemble an upside down parabola.

# %%
mod3 <- lm(df$y3 ~ df$x3)
plot(df$x3, df$y3)
abline(mod3, lwd=2)
grid(nx = NULL,ny = NULL)
msummary(mod3)
# Out:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   3.0025     1.1245   2.670  0.02562 *
# df$x3         0.4997     0.1179   4.239  0.00218 **
#
# Residual standard error: 1.236 on 9 degrees of freedom
# Multiple R-squared:  0.6663,	Adjusted R-squared:  0.6292
# F-statistic: 17.97 on 1 and 9 DF,  p-value: 0.002176
# plot without title

# %%
plot(df$x3, df$y3, xlab = "x3", ylab = "y3", main = "Model 3", xlim=c(4, 15), ylim=c(3, 13))
abline(mod3, lwd=2)
grid(nx = NULL,ny = NULL)

res <- signif(residuals(mod3), 2)
pre <- predict(mod3) # plot distances between points and the regression line
segments(df$x3, df$y3, df$x3, pre, col="red")

# add labels (residual values) to points
#install.packages("calibrate")
library(calibrate)
textxy(df$x3, df$y3, res, cex=0.75)
# Out:
# Plot with title “Model 3”

# %%
plot(df$y3, res, xlab = "predicted", ylab = "actual", main = "Residual Plot for Model 3")
# Out:
# Plot with title “Residual Plot for Model 3”

# %% [markdown]
# Part D model 3
#
# The third model has an R squared value of 0.6292. This means that the model moderately fits the data. There is one point in the data set that has an immense residual value. I would consider classifying that data point as an outlier, due to the fact that is very different from the other data points. After removing the outlier, I would perform the same linear regression and re-evalute the R squared value. If the R squared value dramatically improves, this current model will be considered an adequate model.

# %%
mod4 <- lm(df$y4 ~ df$x4)
plot(df$x4, df$y4, xlab = "x4", ylab = "y4", main = "Model 4")
abline(mod4, lwd=2)
grid(nx = NULL,ny = NULL)
msummary(mod4)
# Out:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   3.0017     1.1239   2.671  0.02559 *
# df$x4         0.4999     0.1178   4.243  0.00216 **
#
# Residual standard error: 1.236 on 9 degrees of freedom
# Multiple R-squared:  0.6667,	Adjusted R-squared:  0.6297
# F-statistic:    18 on 1 and 9 DF,  p-value: 0.002165
# Plot with title “Model 4”

# %%
plot(df$x4, df$y4, xlab = "x4", ylab = "y4", main = "Model 4", xlim=c(7, 15), ylim=c(3, 13))
abline(mod4, lwd=2)
grid(nx = NULL,ny = NULL)

res <- signif(residuals(mod4), 2)
pre <- predict(mod4) # plot distances between points and the regression line
segments(df$x4, df$y4, df$x4, pre, col="red")

# add labels (residual values) to points
#install.packages("calibrate")
library(calibrate)
textxy(df$x4, df$y4, res, cex=0.75)
# Out:
# Plot with title “Model 4”

# %%
plot(df$y4, res, xlab = "predicted", ylab = "actual", main = "Residual Plot for Model 4")
# Out:
# Plot with title “Residual Plot for Model 4”

# %% [markdown]
# Part D Model 4
#
# The fourth model has an R squared value of 0.6297. This means that the model moderately fits the data. Half of the data points have large residual values. Visually, the data looks like a vertical string of points, with one data point to the side. The model does not account for the multiple points at the x4 value of 8. Non-linear functions should be tested on the data in order to find the model that produces the best r squared value. A square root function might be able to fit the data points. The x-value will have to be multiplied by a positive number in order to create a vertical line at the start of the square root function.
